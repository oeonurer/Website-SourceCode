# %%
f = open("site.txt", "r")
print(f.read())
# Out:
# https://www.onureroglu.com.tr
# https://www.dogablogu.net
# https://bilgibilgi.xyz
# https://eniyinetflixfilmleri.com
# https://mycareerguideline.co

# %%
import urllib.request

with open ("site.txt", "r") as f:
    for line in f: 
            L = line 
            print(L)
             
siteadresi = L
htm=urllib.request.urlopen(siteadresi)
print("\n İstediğiniz sitenin kaynak kodu : \n\n")
print(htm.read())
# Out:
# https://www.onureroglu.com.tr
#
# https://www.dogablogu.net
#
# https://bilgibilgi.xyz
#
#  İstediğiniz sitenin kaynak kodu :
#
#
# ...

# %%
#!/usr/bin/python
import urllib.request
import requests


# Open a file
fo = open("site.txt", "r")
print ("Dosyanızın ismi: ", fo.name)

line = fo.readlines()
print ("Okunan satırlar: %s" % (line))



# Close opend file
fo.close()


i=0
# while loop less then list "list_fruits" length
while i < len(line):
    # print the value of i
    print(i)
    # print value of list
    print(line[i])
    i += 1
    

 
siteadresi1 = line[0]
siteadresi2 = line[1]
siteadresi3 = line[2]
siteadresi4 = line[3]
siteadresi5 = line[4]

htm=urllib.request.urlopen(siteadresi1)
print("Site1: İstediğiniz sitenin kaynak kodu: ")
print(htm.read())
htm1=urllib.request.urlopen(siteadresi2)
print("\n\nSite2: İstediğiniz sitenin kaynak kodu: ")
print(htm1.read())
htm2=urllib.request.urlopen(siteadresi3)
print("\n\nSite3: İstediğiniz sitenin kaynak kodu: ")
print(htm2.read())



siteadresi1 = line[0]
r = requests.get(siteadresi)
r = r.text
with open("site1.txt","w",encoding="utf-8") as f:
    f.write(r)
print("İşlem tamamdır.")


siteadresi2 = line[1]
r = requests.get(siteadresi2)
r = r.text
with open("site2.txt","w",encoding="utf-8") as f:
    f.write(r)
print("İşlem tamamdır.")


siteadresi3 = line[2]
r = requests.get(siteadresi3)
r = r.text
with open("site3.txt","w",encoding="utf-8") as f:
    f.write(r)
print("İşlem tamamdır.")

siteadresi4 = line[3]
r = requests.get(siteadresi4)
r = r.text
with open("site4.txt","w",encoding="utf-8") as f:
    f.write(r)
print("İşlem tamamdır.")

siteadresi5 = line[4]
r = requests.get(siteadresi5)
r = r.text
with open("site5.txt","w",encoding="utf-8") as f:
    f.write(r)
print("İşlem tamamdır.")
# Out:
# Dosyanızın ismi:  site.txt
# Okunan satırlar: ['https://www.onureroglu.com.tr\n', 'https://www.dogablogu.net\n', 'https://bilgibilgi.xyz\n', 'https://eniyinetflixfilmleri.com\n', 'https://mycareerguideline.co']
# 0
# https://www.onureroglu.com.tr
#
# 1
# https://www.dogablogu.net
#
# 2
# https://bilgibilgi.xyz
#
# 3
# https://eniyinetflixfilmleri.com
#
# 4
# https://mycareerguideline.co
# Site1: İstediğiniz sitenin kaynak kodu:
# ...
